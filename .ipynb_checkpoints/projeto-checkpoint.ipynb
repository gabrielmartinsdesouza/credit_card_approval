# %% [markdown]
# ## Projeto - Credit Card Approval Prediction

# %% [markdown]
# Esse projeto será realizado através dos datasets contidos em https://www.kaggle.com/datasets/rikdifos/credit-card-approval-prediction
#
# No arquivo estão contidos dois datasets:
#
# **credit_record**: Este data set possui 3 informações. O *ID* do indivíduo, *MONTHS_BALANCE*, que indica o último pago em relação ao mês corrente e *STATUS* que classifica o tempo de vencimento do pagamento caso tenha sido pego algum crédito, se foi pago no mês ou se não há empréstimo para o indivíduo no mês corrente.
#
# **application_record**: Este data set possui informações pessoais referentes a cada indivíduo, que pode ser identificado através do *ID*.
#
# Como resultado desse projeto, deve ser criado um programa no qual será possível idenitificar através do input de informações pessoais se um valor de crédito deve ou não ser aprovado para esta pessoa com base no treinamento das informações disponibilizadas. Para isso, deve ser utilizado um modelo de classificação, capaz de classificar o indivíduo entra **apto** e **não apto** a receber o empréstimo.
#
# #### Como esse modelo pode ser avaliado ?
#
# Inicialmente pretendo avaliar esse modelo através das métricas padrão resultante da matriz de confusão: acurácia, precisão, recall e F1-score. Contudo, visto o contexto de possibilidade de fornecimento de crédito, um foco maior deve ser dado a precisão, visto que erros no fornecimento de crédito específico para aqueles que não deveriam receber e acabam recebendo devido a previsão errônea do modelo acabam tem um potêncial maior de aumento de custo.

# %%
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df_credit_record = pd.read_csv("datasets/credit_record.csv")
df_application_record = pd.read_csv("datasets/application_record.csv")

# %% [markdown]
# Analistando primeiro o dataset que contém as informações é possível perceber que parte das informações de cada indivíduo estão em atributos categóricos e outros em atributos numéricos. Contudo alguns valores categóricos estão em colunas classificadas como numéricas devido a sinalização da categoria ser feita de maneira binária (0-1) Felizmente, no kaggle foi disponibilizado um dicionário dos dados, descrevendo as informações contida em cada um dos atributos.

# %%
df_application_record.shape
# Out:
# (438557, 18)

# %%
df_application_record.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0         427500.00               Working               Higher education
# 1         427500.00               Working               Higher education
# 2         112500.00               Working  Secondary / secondary special
# 3         270000.00  Commercial associate  Secondary / secondary special
# 4         270000.00  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0             NaN
# 1           1                1           0           0             NaN
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS
# 0             2.00
# 1             2.00
# 2             2.00
# 3             1.00
# 4             1.00

# %%
df_application_record.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
#  15  FLAG_EMAIL           438557 non-null  int64
#  16  OCCUPATION_TYPE      304354 non-null  object
#  17  CNT_FAM_MEMBERS      438557 non-null  float64
# dtypes: float64(2), int64(8), object(8)
# memory usage: 60.2+ MB

# %% [markdown]
# É possível perceber que os atributos: *FLAG_MOBIL*, *FLAG_WORK_PHONE*, *FLAG_PHONE* e *FLAG_EMAIL* são na verdade atributos categóricos apesar de terem sido carregados automáticamente como valores inteiros.

# %%
# Verificando linhas duplicadas
df_application_record.duplicated().sum()
# Out:
# 0

# %%
# Verificando se há duplicidade de IDs
df_application_record["ID"].duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 438552    False
# 438553    False
# 438554    False
# 438555    False
# 438556    False
# Name: ID, Length: 438557, dtype: bool

# %% [markdown]
# Foram identificados 47 IDs repetidos. Contudo, devido a grande quantidade de linhas disponíveis e diferentes informações para o mesmo ID, optarei por remover as linhas de IDs repetidas para que não tenha o input de informações incorretas sob um custo de informação baixo comparado a quantidade total de linhas na base de dados (0,0001%).

# %%
47/df_application_record.shape[0]
# Out:
# 0.00010716964955524595

# %%
# Removendo os IDs duplicados.
df_application_record = df_application_record[df_application_record["ID"].duplicated() == False].copy()

# %% [markdown]
# Observando os outros atributos, *DAYS_BIRTH* e *DAYS_EMPLOYED* podem ser convertidos para valores do tipo data. Contudo, como estamos tentando realizar um input em modelo de classificação, o tempo em dias pode ser uma forma mais adequada para a utilização, não necessitando de uma transformação ao formato de data.

# %% [markdown]
# ### Análise Exploratória dos Dados
#
# Para iniciar a EDA, irei inicialmente separar os dados em categóricos e não categóricos, possibilitando a análise em partes. Iniciarei a EDA pelos dados não categóricos, que são a maior parte dos atributos do dataset.

# %%
list(df_application_record)
# Out:
# ['ID',
#  'CODE_GENDER',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_HOUSING_TYPE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'FLAG_MOBIL',
#  'FLAG_WORK_PHONE',
#  'FLAG_PHONE',
#  'FLAG_EMAIL',
#  'OCCUPATION_TYPE',
#  'CNT_FAM_MEMBERS']

# %%
cat_attribs = [
    'ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_INCOME_TYPE',
    'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'FLAG_MOBIL',
    'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE']
num_attribs = [
 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'CNT_FAM_MEMBERS']

# %%
df_ar_cat = df_application_record[cat_attribs]
df_ar_num = df_application_record[num_attribs]

# %% [markdown]
# Antes de iniciar uma análise mais aprofundada do conjunto de dados, irei separar primeiramente os dados de teste e treino na proporção 80/20, dessa forma farei toda análise baseando-se somente no conjunto de treino para evitar um overfitting do modelo aos dados de teste e simular de maneira mais objetiva a entrada de dados novos.

# %%
df_ar_train, df_ar_test = train_test_split(df_application_record,
                                           test_size=0.2,
                                           random_state=42)

# %%
df_ar_cat = df_ar_train[cat_attribs]
df_ar_num = df_ar_train[num_attribs]

# %% [markdown]
# #### Atributos Categóricos

# %%
df_ar_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350808 entries, 282874 to 121958
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   350808 non-null  int64
#  1   CODE_GENDER          350808 non-null  object
#  2   FLAG_OWN_CAR         350808 non-null  object
#  3   FLAG_OWN_REALTY      350808 non-null  object
#  4   NAME_INCOME_TYPE     350808 non-null  object
#  5   NAME_EDUCATION_TYPE  350808 non-null  object
#  6   NAME_FAMILY_STATUS   350808 non-null  object
#  7   NAME_HOUSING_TYPE    350808 non-null  object
#  8   FLAG_MOBIL           350808 non-null  int64
#  9   FLAG_WORK_PHONE      350808 non-null  int64
#  10  FLAG_PHONE           350808 non-null  int64
#  11  FLAG_EMAIL           350808 non-null  int64
#  12  OCCUPATION_TYPE      243442 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 37.5+ MB

# %% [markdown]
# Visualizando todas as variáveis categóricas e o modo como elas se distribuem, é possível notar algumas características interessantes sobre os dados:
# * Dentro da base de dados há o dobro de mulheres em relação aos homens.
# * A maioria das pessoas da base de dados não possuem carro.
# * A maioria possui imóvel próprio.
# * A grande maioria está trabalhando atualmente.
# * A maioria dos indivíduos possuem ensino médio completo.
# * A grande maioria é casada.
# * A grande maioria mora em Casa/Apartamento.
# * Todos os indivíduos possuem telefone celular.
# * A maior parte dos indivíduos não possuem telefone de trabalho.
# * A maior parte dos indivíduos não possuem telefone fixo.
# * A maior parte dos indivíduos não possuem e-mail.
#
# Olhando os gráficos, é possível perceber que os dados estão extremamente desbalanceados em diferentes atributos, o que além de dificultar a análise em si, também dificulta a possibilidade de treinar um modelo sem sobreajustar-lo aos dados que estão em maior quantidade no dataset.
#
# No primeiro momento, identificado que todos os indivíduos analisados possuem telefone celular, é possível excluir esta variável do dados de treino, uma vez que ela possui a mesma informação para todos os indivíduos.

# %%
for attribs in list(df_ar_cat)[1:]:
    categories = df_ar_cat[attribs].value_counts().index
    values = df_ar_cat[attribs].value_counts()
    
    fig, ax = plt.subplots(figsize=(10,5))
    
    bar = ax.bar(categories, values)
    ax.set_title(attribs, fontsize=15)
    ax.bar_label(ax.containers[0], label_type='edge', fontsize=12)

    plt.xticks(fontsize=12, rotation=45)
    plt.show()

# %%
df_ar_cat['FLAG_MOBIL'].value_counts()
# Out:
# FLAG_MOBIL
# 1    350808
# Name: count, dtype: int64

# %%
df_ar_cat["NAME_HOUSING_TYPE"].value_counts().index
# Out:
# Index(['House / apartment', 'With parents', 'Municipal apartment',
#        'Rented apartment', 'Office apartment', 'Co-op apartment'],
#       dtype='object', name='NAME_HOUSING_TYPE')

# %% [markdown]
# Observando as categorias existentes em cada atributo, existem atributos sinalizados com flag, isso é 0-1 indicando falso ou verdadeiro e além disso existem atributos que possuem diversas categorias, como o atributo relacionado ao nível educacional. Para este último, utilizarei a classe OneHotEncoder do scikit-learn para a criação de variáveis dummy.

# %% [markdown]
# #### Atributos Numéricos

# %%
df_ar_cat.head()

# %%
pd.options.display.float_format = "{:.2f}".format  # Alterando o formato de exibição do pandas para evitar notação científica.
df_ar_num.describe()

# %%
df_ar_cat[ID].value_counts()

# %%
df_ar_cat["ID"].value_counts()

# %%
df_ar_train.shape

# %%
df_ar_test.shape

# %%
87702/438557
